# %%
import matplotlib.pyplot as plt
import numpy as np


Fs = 1000
f = 150
x = np.linspace(0, 100, 1000)
hight = np.cos(x / 10) * np.exp(-x / 35) + 1
plt.figure(figsize=(12, 3))
plt.plot(x, hight, "r")
y = hight * np.sin(2 * np.pi * f * x / Fs)
plt.plot(x, abs(y), "black")
plt.axhline(y=1, linestyle="--")
plt.xlabel("Time(s)")
plt.ylabel("Ventialtion")
plt.show()
# Out:
# Text(0.5, 0, 'Time(s)')
# Text(0, 0.5, 'Ventialtion')

# %%
import matplotlib.pyplot as plt
import numpy as np


Fs = 1000
f = 150
x = np.linspace(0, 100, 1000)
hight = np.exp(-x / 10) + 1.33
plt.figure(figsize=(12, 3))
plt.plot(x, 0.75 * hight, color="green")
y = 0.75 * hight * np.sin(2 * np.pi * f * x / Fs)
plt.plot(x, abs(y), color="black")
plt.axhline(y=1, linestyle="--")
plt.ylim(top=2)
plt.xlabel("Time(s)")
plt.ylabel("Ventialtion")
plt.show()
# Out:
# (-0.08737500000000001, 2.0)
# Text(0.5, 0, 'Time(s)')
# Text(0, 0.5, 'Ventialtion')

# %%
import matplotlib.pyplot as plt
import numpy as np


Fs = 1000
f = 150
x = np.linspace(0, 100, 1000)
hight = np.exp(-x / 70) + 1.45
plt.figure(figsize=(12, 3))
plt.plot(x, 0.6 * hight, color="blue")
y = 0.6 * hight * np.sin(2 * np.pi * f * x / Fs)
plt.plot(x, abs(y), color="black")
plt.axhline(y=1, linestyle="--")
plt.ylim(top=2)
plt.xlabel("Time(s)")
plt.ylabel("Ventialtion")
plt.show()
# Out:
# (-0.0735, 2.0)
# Text(0.5, 0, 'Time(s)')
# Text(0, 0.5, 'Ventialtion')
